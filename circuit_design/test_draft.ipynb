# %% [markdown]
# ### Test script on register

# %%
% run -i 'run_verification_on_register.py' 'examples/test_register.csv' '../../../notebooks_GRNs/designs/A030-thesis-count8/changes.txt' 'examples/' 'puyol' False
# Out:
# **********************
# Coming change to:  ['d_1_BP_site_R', 'd_1_BP_site_L']  iter:  0
# **********************
# Coming change to:  ['c_1_BP_site_R', 'c_1_BP_site_L']  iter:  1
# **********************
# Coming change to:  ['d_1_LR_site_R', 'd_1_LR_site_L']  iter:  2
# **********************
# Coming change to:  ['a_1_BP_site_R', 'a_1_BP_site_L']  iter:  3
# **********************
# Coming change to:  ['d_1_BP_site_R', 'd_1_BP_site_L']  iter:  4
# **********************
# Coming change to:  ['c_1_LR_site_R', 'c_1_LR_site_L']  iter:  5
# **********************
# Coming change to:  ['d_1_LR_site_R', 'd_1_LR_site_L']  iter:  6

# %% [markdown]
# ### Test script on counter

# %%
% run -i 'run_verification_on_counter.py' 'examples/test_counter.csv' 'examples/' False
# Out:
# **********************
# **********************
# current count:  1  to  2
# old:  b_1_LR_site_R  new:  b_1_LR_site_R
# old:  0_promoter_U  new:  0_promoter_U
# old:  b_1_LR_site_L  new:  b_1_LR_site_L
# old:  a_1_BP_site_R  new:  a_1_BP_site_R
# old:  c_1_BP_site_R  new:  c_1_BP_site_R
# old:  d_1_BP_site_R  new:  d_1_LR_site_R  <------- CHANGE IN THIS LINE !
# old:  0_promoter_D  new:  0_terminator_D  <------- CHANGE IN THIS LINE !
# old:  d_cassette_U  new:  d_cassette_D  <------- CHANGE IN THIS LINE !
# old:  0_terminator_U  new:  0_promoter_U  <------- CHANGE IN THIS LINE !
# old:  d_1_BP_site_L  new:  d_1_LR_site_L  <------- CHANGE IN THIS LINE !
# old:  0_promoter_D  new:  0_promoter_D
# old:  c_cassette_U  new:  c_cassette_U
# old:  0_terminator_U  new:  0_terminator_U
# old:  0_terminator_D  new:  0_terminator_D
# old:  d_reversal_fac_D  new:  d_reversal_fac_D
# old:  c_1_BP_site_L  new:  c_1_BP_site_L
# old:  a_cassette_U  new:  a_cassette_U
# ...
