# %%
% run -i 'run_dev_tree.py' '../block_definition/examples/Graph_G_5_msp_sphere' '../block_definition/examples/G_5_msp_sphere.txt' 'tetrahedron' 'examples/test.npy' False
# Out:
# ************
# ************
# level index 5
# *****
# node 31
# cell register after loop ['0_ex_gene_D', '0_in_gene_D']
# *****
# node 32
# cell register after loop ['0_ex_gene_D', '0_in_gene_D']
# *****
# node 33
# cell register after loop ['0_ex_gene_D', '0_in_gene_D']
# *****
# node 34
# cell register after loop ['0_ex_gene_D', '0_in_gene_D']
# *****
# node 35
# cell register after loop ['0_ex_gene_D', '1_in_gene_D']
# *****
# node 36
# cell register after loop ['0_ex_gene_D', '1_in_gene_D']
# *****
# node 37
# cell register after loop ['0_ex_gene_D', '1_in_gene_D']
# *****
# node 38
# cell register after loop ['1_in_gene_D']
# *****
# node 39
# cell register after loop ['0_ex_gene_D', '2_in_gene_D']
# *****
# node 40
# cell register after loop ['0_ex_gene_D', '2_in_gene_D']
# *****
# node 41
# cell register after loop ['2_in_gene_D']
# *****
# node 42
# cell register after loop ['2_in_gene_D']
# *****
# node 43
# cell register after loop ['0_ex_gene_D', '3_in_gene_D']
# *****
# ...
